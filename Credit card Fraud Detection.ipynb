# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#checking the first 5 rows of the data
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#here checking the last 5 rows of the data
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
#getting the general information about the datalike data type of each coloum
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df['Class'].value_counts() #0 for non-fraud,1 for fraud
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 1.Here 0 represents the normal transactions and 1 represents fraud transactions
#
# 2.And we can see that, this is imbalanced dataset as there are two types of target variables and from that more than 98 to 99% of the data is present in the first variabel only
#
# 3.And for that we can use different techniques to deal with the imbalance dataset like under sampling or over sampling

# %%
#checking if there are any null or NaN Values in the dataset or not
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#In this data set their is no Null value is present

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df=df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.duplicated().any() # any is the parameter of duplicated
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %% [markdown]
# # EDA(Exploratory data analysis)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#checking the class distribution of the target variable

# %%
print((df.groupby('Class')['Class'].count()/df['Class'].count())*100)
((df.groupby('Class')['Class'].count()/df['Class'].count())*100).plot.pie()
# Out:
# Class
# 0    99.828414
# 1     0.171586
# Name: Class, dtype: float64
# <AxesSubplot:ylabel='Class'>

# %%
#bank 99% is real transaction only 0.17 is farud transaction.

# %%
import seaborn as sns

# %%
sns.countplot(df['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
# minor red is showing

# %%
corr=df.corr() #we are seening the realtionship between the dataset
corr
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# V1      1.000000  0.009002  0.005952 -0.000042 -0.018593 -0.005789 -0.006843
# V2      0.009002  1.000000  0.004976 -0.004095  0.004655  0.004290  0.004866
# V3      0.005952  0.004976  1.000000 -0.000721  0.011020  0.014780 -0.014016
# V4     -0.000042 -0.004095 -0.000721  1.000000  0.006710  0.012535  0.000806
# V5     -0.018593  0.004655  0.011020  0.006710  1.000000 -0.029701 -0.009107
# V6     -0.005789  0.004290  0.014780  0.012535 -0.029701  1.000000  0.013087
# V7     -0.006843  0.004866 -0.014016  0.000806 -0.009107  0.013087  1.000000
# V8     -0.000490  0.003743  0.003733  0.004996 -0.002605 -0.012301 -0.000987
# V9     -0.007093  0.001116 -0.002896  0.001395 -0.000786 -0.002290 -0.001657
# V10     0.003115  0.002764 -0.011064  0.003366 -0.002818 -0.002723 -0.012246
# V11    -0.005238 -0.001808  0.003763 -0.004402 -0.002965  0.000446  0.001731
# ...

# %%
plt.figure(figsize=(24,28))
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# #drak shades shows high realtionship between the variables while lighter shades shows less realtionship between the variable.

# %%
y=df['Class']
x=df.drop(['Class'],axis=1)

# %%
x.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1089,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.999288989494457

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
 precision_score(y_test,y_pred1)
# Out:
# 0.8876404494382022

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.6694915254237288

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7632850241545893

# %% [markdown]
# # undersampling

# %%
normal=df[df['Class']==0]
fraud=df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([normal_sample,fraud])

# %%
new_data['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_data.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 66839  -1.288576  0.411500  0.304297 -1.531243  3.581805 -1.784578 -5.446399
# 63076  -1.161103  0.896858  1.542697  3.112279 -0.413786  0.165328  0.057026
# 203567 -1.121603  1.964268 -1.628258 -0.429217  0.308405 -0.930464  0.221081
# 204837  1.776652 -0.456574 -0.521360  1.278753 -0.374586 -0.035029 -0.382870
# 72929  -0.190366  1.224816  1.143958  1.321247  0.452607 -0.350894  0.954524
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 66839  -5.336273  0.662655 -1.894025  ... -2.625483 -0.249006 -6.256749
# 63076   0.693806 -1.370514  0.637554  ...  0.008368 -0.166447  0.137776
# 203567  0.686098 -0.239209 -0.347317  ...  0.326702  1.044575 -0.130294
# 204837  0.001488  0.867578  0.165373  ...  0.275504  0.685058  0.065908
# 72929  -0.241367 -1.115661 -0.052433  ...  0.060552  0.284350 -0.286203
#
# ...

# %%
x=new_data.drop('Class',axis=1)
y=df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
y_pred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.8876404494382022

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.6694915254237288

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7632850241545893

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
df=DecisionTreeClassifier()
df.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=df.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.999288989494457

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.8050847457627118

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.794979079497908

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9995937082825469

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.96875

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.788135593220339

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.794979079497908

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF'],
             'ACC':[accuracy_score(y_test,y_pred1)*100,
                   accuracy_score(y_test,y_pred2)*100,
                   accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  99.928899
# 1     DT  99.928899
# 2     RF  99.959371

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # OVERSAMPLING

# %%
Log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.999288989494457

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7632850241545893

# %% [markdown]
# # Decision tree classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.999288989494457

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.7899159663865546

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.7966101694915254

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.7932489451476793

# %% [markdown]
# # random forest after oversampling

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(x_test)

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.7966101694915254

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.8744186046511628

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF'],
             'ACC':[accuracy_score(y_test,y_pred1)*100,
                   accuracy_score(y_test,y_pred2)*100,
                   accuracy_score(y_test,y_pred3)*100]})

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='ACC'>
